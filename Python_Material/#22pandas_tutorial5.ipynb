# %%
#Sorting & Ranking in Pandas

import pandas as pd
import numpy as np

# %%
data=pd.read_csv("bank.csv")

# %%
data.head(3)
# Out:
#     age         job  marital  education default  balance housing loan  \
# 0  59.0      admin.  married  secondary      no     2343     yes   no
# 1  56.0      admin.  married  secondary      no       45      no   no
# 2  41.0  technician  married  secondary      no     1270     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit
# 0  unknown    5   may      1042         1     -1         0  unknown     yes
# 1  unknown    5   may      1467         1     -1         0  unknown     yes
# 2  unknown    5   may      1389         1     -1         0  unknown     yes

# %%
data["age"].sort_values(ascending=False)
# Out:
# 1582    95.0
# 3822    93.0
# 3756    93.0
# 2802    92.0
# 3098    92.0
#         ...
# 4219    18.0
# 2464    18.0
# 3174    18.0
# 14       NaN
# 37       NaN
# Name: age, Length: 11162, dtype: float64

# %%
data.sort_values("balance")
# Out:
#         age            job   marital  education default  balance housing loan  \
# 6797   49.0     management   married   tertiary     yes    -6847      no  yes
# 1525   39.0  self-employed   married   tertiary      no    -3058     yes  yes
# 10642  52.0     management   married   tertiary      no    -2712     yes  yes
# 6388   51.0     management  divorced   tertiary      no    -2282     yes  yes
# 6010   49.0     management  divorced   tertiary      no    -2049     yes   no
# ...     ...            ...       ...        ...     ...      ...     ...  ...
# 3236   61.0  self-employed  divorced   tertiary      no    52587      no   no
# 10143  43.0         admin.    single  secondary      no    56831      no   no
# 8208   52.0    blue-collar   married    primary      no    66653      no   no
# 3043   84.0        retired   married  secondary      no    81204      no   no
# 3380   84.0        retired   married  secondary      no    81204      no   no
#
# ...

# %%
data.sort_values(["age","balance"])
# Out:
#        age         job   marital  education default  balance housing loan  \
# 4219  18.0     student    single    unknown      no        3      no   no
# 6456  18.0     student    single  secondary      no        5      no   no
# 2464  18.0     student    single    unknown      no      108      no   no
# 2654  18.0     student    single    unknown      no      108      no   no
# 3174  18.0     student    single    unknown      no      108      no   no
# ...    ...         ...       ...        ...     ...      ...     ...  ...
# 3756  93.0     retired   married    unknown      no      775      no   no
# 3822  93.0     retired   married    unknown      no      775      no   no
# 1582  95.0     retired  divorced    primary      no     2282      no   no
# 37     NaN  management  divorced  secondary      no        5     yes   no
# 14     NaN  technician    single   tertiary      no      703     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
print(data.age.isnull())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11157    False
# 11158    False
# 11159    False
# 11160    False
# 11161    False
# Name: age, Length: 11162, dtype: bool

# %%
data.age.notnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 11157    True
# 11158    True
# 11159    True
# 11160    True
# 11161    True
# Name: age, Length: 11162, dtype: bool

# %%
data.head(16)
# Out:
#      age          job   marital  education default  balance housing loan  \
# 0   59.0       admin.   married  secondary      no     2343     yes   no
# 1   56.0       admin.   married  secondary      no       45      no   no
# 2   41.0   technician   married  secondary      no     1270     yes   no
# 3   55.0     services   married  secondary      no     2476     yes   no
# 4   54.0       admin.   married   tertiary      no      184      no   no
# 5   42.0   management    single   tertiary      no        0     yes  yes
# 6   56.0   management   married   tertiary      no      830     yes  yes
# 7   60.0      retired  divorced  secondary      no      545     yes   no
# 8   37.0   technician   married  secondary      no        1     yes   no
# 9   28.0     services    single  secondary      no     5090     yes   no
# 10  38.0       admin.    single  secondary      no      100     yes   no
# 11  30.0  blue-collar   married  secondary      no      309     yes   no
# ...

# %%
data.age.dropna()
# Out:
# 0        59.0
# 1        56.0
# 2        41.0
# 3        55.0
# 4        54.0
#          ...
# 11157    33.0
# 11158    39.0
# 11159    32.0
# 11160    43.0
# 11161    34.0
# Name: age, Length: 11160, dtype: float64

# %%
null_mask = data.age.isnull()
null_rows = data[null_mask]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, deposit]
# Index: []

# %%
data.age.fillna(data.age.mean(),inplace=True)

# %%
null_mask = data.age.isnull()
null_rows = data[null_mask]

print(null_rows)
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, deposit]
# Index: []

# %%
import pandas as pd

# %%
bank=pd.read_csv("bank.csv")

# %%
bank.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
bank.head(3)
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes

# %%
bank.tail()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# ...

# %%
bank.tail(10)
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11152   34    housemaid  married  secondary      no      390     yes   no
# 11153   43       admin.   single  secondary      no       35      no   no
# 11154   52   technician  married   tertiary      no      523     yes  yes
# 11155   35  blue-collar  married  secondary      no       80     yes  yes
# 11156   34  blue-collar   single  secondary      no      -72     yes   no
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 11152   cellular   15   jul       659         3     -1         0  unknown
# ...

# %%
bank["age"]
#bank["loan"]
# Out:
# 0        59
# 1        56
# 2        41
# 3        55
# 4        54
#          ..
# 11157    33
# 11158    39
# 11159    32
# 11160    43
# 11161    34
# Name: age, Length: 11162, dtype: int64

# %%
bank.age
# Out:
# 0        59
# 1        56
# 2        41
# 3        55
# 4        54
#          ..
# 11157    33
# 11158    39
# 11159    32
# 11160    43
# 11161    34
# Name: age, Length: 11162, dtype: int64

# %%
bank[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
bank.loc[0]
# Out:
# age                 59
# job             admin.
# marital        married
# education    secondary
# default             no
# balance           2343
# housing            yes
# loan                no
# contact        unknown
# day                  5
# month              may
# duration          1042
# campaign             1
# pdays               -1
# previous             0
# poutcome       unknown
# deposit            yes
# Name: 0, dtype: object

# %%
bank.head(3)
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes

# %%
bank["age"]=75
bank
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       75       admin.  married  secondary      no     2343     yes   no
# 1       75       admin.  married  secondary      no       45      no   no
# 2       75   technician  married  secondary      no     1270     yes   no
# 3       75     services  married  secondary      no     2476     yes   no
# 4       75       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   75  blue-collar   single    primary      no        1     yes   no
# 11158   75     services  married  secondary      no      733      no   no
# 11159   75   technician   single  secondary      no       29      no   no
# 11160   75   technician  married  secondary      no        0      no  yes
# 11161   75   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
bank=pd.read_csv("bank.csv")
bank.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
bank["age1"]=bank.age<=55
bank.head(10)
# Out:
#    age         job   marital  education default  balance housing loan  \
# 0   59      admin.   married  secondary      no     2343     yes   no
# 1   56      admin.   married  secondary      no       45      no   no
# 2   41  technician   married  secondary      no     1270     yes   no
# 3   55    services   married  secondary      no     2476     yes   no
# 4   54      admin.   married   tertiary      no      184      no   no
# 5   42  management    single   tertiary      no        0     yes  yes
# 6   56  management   married   tertiary      no      830     yes  yes
# 7   60     retired  divorced  secondary      no      545     yes   no
# 8   37  technician   married  secondary      no        1     yes   no
# 9   28    services    single  secondary      no     5090     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome deposit  \
# 0  unknown    5   may      1042         1     -1         0  unknown     yes
# ...

# %%
bank.age1.head(20)
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# Name: age1, dtype: bool

# %%
del bank["age1"]
bank
# Out:
#        age          job  marital  education default  balance housing loan  \
# 0       59       admin.  married  secondary      no     2343     yes   no
# 1       56       admin.  married  secondary      no       45      no   no
# 2       41   technician  married  secondary      no     1270     yes   no
# 3       55     services  married  secondary      no     2476     yes   no
# 4       54       admin.  married   tertiary      no      184      no   no
# ...    ...          ...      ...        ...     ...      ...     ...  ...
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# ...

# %%
my_colums = ["age","job"]
bank[my_colums]
# Out:
#        age          job
# 0       59       admin.
# 1       56       admin.
# 2       41   technician
# 3       55     services
# 4       54       admin.
# ...    ...          ...
# 11157   33  blue-collar
# 11158   39     services
# 11159   32   technician
# 11160   43   technician
# 11161   34   technician
#
# [11162 rows x 2 columns]

# %%
#bank["age":"job"] ---" need to check how to fetch details for series of 2 columns"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 bank["age":"job"]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3779, in DataFrame.__getitem__(self, key)
#    3777         return self._getitem_multilevel(key)
#    3778 # Do we have a slicer (on rows)?
# -> 3779 indexer = convert_to_index_sliceable(self, key)
#    3780 if indexer is not None:
#    3781     if isinstance(indexer, np.ndarray):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:2494, in convert_to_index_sliceable(obj, key)
#    2492 idx = obj.index
#    2493 if isinstance(key, slice):
# -> 2494     return idx._convert_slice_indexer(key, kind="getitem")
#    2496 elif isinstance(key, str):
#    2497
#    2498     # we are an actual column
#    2499     if key in obj.columns:
#
# ...

# %%
bank.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# deposit      object
# dtype: object

# %%
bank.age.head(3)
# Out:
# 0    59
# 1    56
# 2    41
# Name: age, dtype: int64

# %%
df=pd.DataFrame(bank,columns=["age","job","marital","housing","loan"])
df
# Out:
#        age          job  marital housing loan
# 0       59       admin.  married     yes   no
# 1       56       admin.  married      no   no
# 2       41   technician  married     yes   no
# 3       55     services  married     yes   no
# 4       54       admin.  married      no   no
# ...    ...          ...      ...     ...  ...
# 11157   33  blue-collar   single     yes   no
# 11158   39     services  married      no   no
# 11159   32   technician   single      no   no
# 11160   43   technician  married      no  yes
# 11161   34   technician  married      no   no
#
# [11162 rows x 5 columns]

# %%
bank.age.describe()
#a = bank.age
#a.describe()
# Out:
# count    11162.000000
# mean        41.231948
# std         11.913369
# min         18.000000
# 25%         32.000000
# 50%         39.000000
# 75%         49.000000
# max         95.000000
# Name: age, dtype: float64

# %%
bank.age.value_counts()
# Out:
# 31    496
# 32    477
# 34    466
# 33    464
# 35    461
#      ...
# 92      2
# 93      2
# 88      2
# 95      1
# 89      1
# Name: age, Length: 76, dtype: int64

# %%
bank.age.value_counts(normalize=True) #it make sure to keep data in 0,1 based on min and max
# Out:
# 31    0.044436
# 32    0.042734
# 34    0.041749
# 33    0.041570
# 35    0.041301
#         ...
# 92    0.000179
# 93    0.000179
# 88    0.000179
# 95    0.000090
# 89    0.000090
# Name: age, Length: 76, dtype: float64

# %%
type(bank.age.value_counts())
# Out:
# pandas.core.series.Series

# %%
bank.age.value_counts().head()
# Out:
# 31    496
# 32    477
# 34    466
# 33    464
# 35    461
# Name: age, dtype: int64

# %%
bank.age.unique()
# Out:
# array([59, 56, 41, 55, 54, 42, 60, 37, 28, 38, 30, 29, 46, 31, 35, 32, 49,
#        43, 26, 40, 33, 23, 48, 45, 36, 52, 53, 39, 57, 51, 44, 24, 50, 27,
#        34, 47, 25, 58, 61, 68, 75, 22, 69, 66, 85, 72, 90, 67, 71, 21, 74,
#        65, 62, 83, 70, 76, 77, 19, 73, 63, 20, 78, 95, 64, 79, 82, 18, 86,
#        84, 87, 92, 81, 80, 93, 88, 89])

# %%
bank.age.nunique()
# Out:
# 76

# %%
pd.crosstab(bank.age, bank.job)
# Out:
# job  admin.  blue-collar  entrepreneur  housemaid  management  retired  \
# age
# 18        0            0             0          0           0        0
# 19        0            0             0          0           0        0
# 20        1            2             0          0           0        0
# 21        1            4             1          0           1        0
# 22        5            2             0          1           3        0
# ..      ...          ...           ...        ...         ...      ...
# 89        0            0             0          0           0        1
# 90        0            0             0          0           0        2
# 92        0            0             0          0           0        2
# 93        0            0             0          0           0        2
# 95        0            0             0          0           0        1
#
# job  self-employed  services  student  technician  unemployed  unknown
# age
# ...

# %%
bank.age.mean()

# %%
bank.age.plot(kind="hist")

# %%
bank.job.value_counts().plot(kind="bar")

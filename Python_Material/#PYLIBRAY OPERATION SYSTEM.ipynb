# %%
import os

# %%
os.getcwd() #get current directory

#!pwd -- shortcut
# Out:
# '/Users/akshithkumardhuvvuru'

# %%
os.listdir() #list all files in our directory
# Out:
# ['transforms_tutorial.ipynb',
#  '#25json_format.ipynb',
#  '#20exceptional_handling.ipynb',
#  '#22pandas_tutorial4.ipynb',
#  '.config',
#  'Music',
#  '#12lambda_fun.ipynb',
#  '.condarc',
#  'Factorial_pgm.ipynb',
#  '#7Casting.ipynb',
#  'Salary_Data.csv',
#  'colors.ipynb',
#  'bank.csv',
#  'ML_CLASS1.ipynb',
#  'patheffects_guide.ipynb',
#  '#22pandas_tutorial6.ipynb',
#  '#12Function_tutorial.ipynb',
#  'regular_expression.ipynb',
#  'xmltojson_ex1.ipynb',
#  '.DS_Store',
#  'mathtext.ipynb',
#  'data_processing.ipynb',
#  'legend_guide.ipynb',
#  'Apriori_algorithm_sample1.ipynb',
#  '#34MATH_BAR.ipynb',
#  '.CFUserTextEncoding',
#  '#2Operators.ipynb',
#  'TitanicData.ipynb',
#  '#91simple_linear_regression_ex2.ipynb',
#  'Market_Basket_Optimisation.csv',
#  'final_data.csv',
#  '.xonshrc',
#  'wine_data.csv',
#  '#8SET_MATERIAL.ipynb',
#  'Untitled.ipynb',
#  '.zshrc',
#  'LinearReg.ipynb',
#  'text_intro.ipynb',
#  'artists.ipynb',
#  '#31MATH_TUT2.ipynb',
# ...

# %%
os.makedirs('sample_for_testing')

# %%
os.listdir()
# Out:
# ['transforms_tutorial.ipynb',
#  '#25json_format.ipynb',
#  '#20exceptional_handling.ipynb',
#  '#22pandas_tutorial4.ipynb',
#  '.config',
#  'Music',
#  '#12lambda_fun.ipynb',
#  '.condarc',
#  'Factorial_pgm.ipynb',
#  '#7Casting.ipynb',
#  'Salary_Data.csv',
#  'colors.ipynb',
#  'bank.csv',
#  'ML_CLASS1.ipynb',
#  'patheffects_guide.ipynb',
#  '#22pandas_tutorial6.ipynb',
#  '#12Function_tutorial.ipynb',
#  'regular_expression.ipynb',
#  'xmltojson_ex1.ipynb',
#  '.DS_Store',
#  'mathtext.ipynb',
#  'data_processing.ipynb',
#  'legend_guide.ipynb',
#  'Apriori_algorithm_sample1.ipynb',
#  '#34MATH_BAR.ipynb',
#  '.CFUserTextEncoding',
#  '#2Operators.ipynb',
#  'TitanicData.ipynb',
#  '#91simple_linear_regression_ex2.ipynb',
#  'Market_Basket_Optimisation.csv',
#  'final_data.csv',
#  '.xonshrc',
#  'wine_data.csv',
#  '#8SET_MATERIAL.ipynb',
#  '.zshrc',
#  'LinearReg.ipynb',
#  'text_intro.ipynb',
#  'artists.ipynb',
#  '#31MATH_TUT2.ipynb',
#  'matplotlib.ipynb',
# ...

# %%
#alternake for creating directory
os.makedirs(os.path.join('test_for_os'))

# %%
os.listdir()
# Out:
# ['transforms_tutorial.ipynb',
#  '#25json_format.ipynb',
#  '#20exceptional_handling.ipynb',
#  '#22pandas_tutorial4.ipynb',
#  '.config',
#  'Music',
#  '#12lambda_fun.ipynb',
#  '.condarc',
#  'Factorial_pgm.ipynb',
#  '#7Casting.ipynb',
#  'Salary_Data.csv',
#  'colors.ipynb',
#  'bank.csv',
#  'ML_CLASS1.ipynb',
#  'patheffects_guide.ipynb',
#  '#22pandas_tutorial6.ipynb',
#  '#12Function_tutorial.ipynb',
#  'regular_expression.ipynb',
#  'xmltojson_ex1.ipynb',
#  '.DS_Store',
#  'mathtext.ipynb',
#  'data_processing.ipynb',
#  'legend_guide.ipynb',
#  'Apriori_algorithm_sample1.ipynb',
#  '#34MATH_BAR.ipynb',
#  '.CFUserTextEncoding',
#  '#2Operators.ipynb',
#  'TitanicData.ipynb',
#  '#91simple_linear_regression_ex2.ipynb',
#  'Market_Basket_Optimisation.csv',
#  'final_data.csv',
#  '.xonshrc',
#  'wine_data.csv',
#  '#8SET_MATERIAL.ipynb',
#  '.zshrc',
#  'LinearReg.ipynb',
#  'text_intro.ipynb',
#  'artists.ipynb',
#  '#31MATH_TUT2.ipynb',
#  'matplotlib.ipynb',
# ...

# %%
os.remove('os_testing.txt')

# %%
os.rename('test_for_os','testing_for_os')

# %%
os.rmdir('testing_for_os')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 os.rmdir('testing_for_os')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testing_for_os'
